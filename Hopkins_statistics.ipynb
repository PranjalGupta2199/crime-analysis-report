# %% [markdown]
# # Hopkins Statistics

# %%
from sklearn.neighbors import BallTree
import numpy as np
import pandas as pd
from sklearn.preprocessing import scale

# %% [markdown]
# The Hopkins statistic is a way of measuring the cluster tendency of a data set. It belongs to the family of sparse sampling tests.

# %%
# dataset = pd.read_csv('./Absenteeism_at_work.csv', sep=';')
dataset = pd.read_pickle('./state_clubbed_df.pickle')
sampling_size = 350

# %%
rows, columns = dataset.shape
print ("Total rows : {}\t Total columns: {}".format(rows, columns))
# Out:
# Total rows : 527	 Total columns: 13

# %%
dataset.head()
# Out:
#                state  year  murder   rape  foeticide  \
# 0     andhra pradesh  2001    35.0   84.0        0.0
# 1  arunachal pradesh  2001     0.0    0.0        0.0
# 2              assam  2001     0.0    0.0        0.0
# 3              bihar  2001     2.0   16.0        0.0
# 4       chhattisgarh  2001    14.0  150.0        5.0
#
#    kidnapping and abduction  abetment of suicide  exposure and abandonment  \
# 0                      57.0                  7.0                      22.0
# 1                       0.0                  0.0                       0.0
# 2                      18.0                  0.0                       0.0
# 3                      26.0                  0.0                       1.0
# 4                      46.0                  1.0                      15.0
#
#    procuration of minor girls  selling girls for prostitution  \
# 0                        12.0                             0.0
# 1                         0.0                             0.0
# 2                         0.0                             0.0
# 3                        16.0                             1.0
# 4                         0.0                             0.0
#
#    prohibition of child marriage act  other crimes  total
# 0                                6.0          47.0  270.0
# 1                                0.0           0.0    0.0
# 2                                0.0           0.0   18.0
# 3                                2.0          18.0   83.0
# 4                                0.0         354.0  585.0

# %%
# Scaling and Preprocessing the dataset

dataset.drop(['state', 'year', 'total'], axis=1, inplace=True)
dataset = pd.DataFrame(scale(dataset))

# %%
# Sample n observations from D : P

if sampling_size > dataset.shape[0]:
    raise Exception(
        'The number of sample of sample is bigger than the shape of D')

sample_dataset = dataset.sample(n=sampling_size)
sample_dataset.shape
# Out:
# (350, 10)

# %%
sample_dataset.head()
# Out:
#             0         1         2         3         4         5         6  \
# 423  0.720329 -0.287126 -0.288881  0.860949 -0.281905 -0.417052  1.899639
# 520 -0.505852 -0.474831 -0.422895 -0.362013 -0.281905 -0.398377 -0.216594
# 510 -0.272878  2.734926 -0.422895  0.654999 -0.281905 -0.417052 -0.139839
# 382 -0.039903  0.504364  0.247176  3.353584 -0.281905  0.834176 -0.183699
# 110 -0.493590 -0.493601 -0.422895 -0.382184 -0.281905 -0.417052 -0.205629
#
#             7         8         9
# 423  0.089764 -0.320520 -0.357693
# 520 -0.183679 -0.320520 -0.324346
# 510 -0.183679 -0.320520 -0.170120
# 382 -0.001384 -0.442216  0.167510
# 110 -0.183679 -0.442216 -0.345188

# %%
# Get the distance to their neirest neighbors in D : X

tree = BallTree(dataset, leaf_size=2)
dist, _ = tree.query(sample_dataset, k=2)
sample_knn_dist = dist[:, 1]

# %%
sample_knn_dist
# Out:
# array([7.76514413e-01, 7.87533554e-02, 1.21282462e+00, 5.45582309e-01,
#        3.55557130e-02, 2.27328781e-01, 5.62756423e-03, 2.14411993e-02,
#        1.24442782e-02, 1.90387727e-02, 2.32234616e-02, 1.44975519e+00,
#        5.64092479e-02, 1.05081060e+00, 1.00152818e-01, 2.89754961e-01,
#        0.00000000e+00, 1.64480840e+00, 3.67324157e-01, 0.00000000e+00,
#        1.02687480e-01, 1.03626282e-01, 1.22618143e-02, 5.17869113e-01,
#        6.67646030e-02, 4.91395561e-01, 2.00096472e-01, 0.00000000e+00,
#        1.16262272e+00, 4.15350717e-01, 0.00000000e+00, 4.30297107e+00,
#        1.18437479e+00, 1.57003598e+00, 8.53659731e-01, 1.26714855e-01,
#        1.08853347e-01, 7.40501754e-02, 1.31839299e-01, 1.26686630e-02,
#        1.01815988e-01, 3.32705481e-02, 1.28937023e+00, 7.15177607e-01,
#        2.93591612e-02, 0.00000000e+00, 1.59614857e+00, 5.76624545e-02,
#        1.04827806e+00, 4.58050763e-01, 1.72292368e+00, 1.46759803e+00,
#        1.64811693e+00, 2.45172932e-02, 1.29295732e-01, 3.10794884e-01,
#        2.39917867e+00, 2.04115495e-02, 7.02226866e-01, 3.30363296e-03,
#        2.93217870e-01, 3.74776685e+00, 4.15350717e-01, 4.67787143e-03,
#        7.19765020e-01, 3.68091254e-02])

# %%
# Randomly simulate n points with the same variation as in D : Q.

max_data = dataset.max()
min_data = dataset.min()

uniform_sel_x = np.random.uniform(min_data[0], max_data[0], sampling_size)
uniform_sel_y = np.random.uniform(min_data[1], max_data[1], sampling_size)

uniform_obsv = np.column_stack((uniform_sel_x, uniform_sel_y))
if len(max_data) >= 2:
    for i in range(2, len(max_data)):
        temp = np.random.uniform(min_data[i], max_data[i], sampling_size)
        to_stack = (uniform_obsv, temp)
        uniform_obsv = np.column_stack(to_stack)

uniform_obsv_df = pd.DataFrame(uniform_obsv)
uniform_obsv_df.columns = dataset.columns

# %%
uniform_obsv_df.shape
# Out:
# (350, 10)

# %%
uniform_obsv_df.head()
# Out:
#           0         1         2         3          4         5         6  \
# 0  6.025616  4.684547  1.082696  5.489314  15.654607  3.141435  0.455805
# 1  4.451753  6.327531  5.295906  0.549737   2.939737  2.237436  9.896995
# 2  2.989599  0.298279  4.810684  1.636181   6.908516  2.966611  2.373934
# 3  4.418234  3.081694  2.844432  4.865856  12.588519  2.141714  9.953272
# 4  5.120453  4.607725  0.788100  6.102180  15.478150  3.470753  6.883838
#
#           7         8         9
# 0  3.547502  2.309592  4.107076
# 1  6.807954  0.141895  4.173665
# 2  7.395206  5.450528  1.533384
# 3  9.463286  3.880438  2.827955
# 4  6.653271  6.882474  6.740676

# %%
# Get the distance to their neirest neighbors in D : Y

tree = BallTree(dataset, leaf_size=2)
dist, _ = tree.query(uniform_obsv_df, k=1)
uniform_knn_dist = dist

# %%
# Calculate the Hopkins Score

x = sum(sample_knn_dist)
y = sum(uniform_knn_dist)

if x + y == 0:
    raise Exception('The denominator of the hopkins statistics is null')

h_stat = (y[0] / (x + y)[0])
print ("The hopkins statistics measure is {}".format(h_stat))
# Out:
# The hopkins statistics measure is 0.9561462031392631
